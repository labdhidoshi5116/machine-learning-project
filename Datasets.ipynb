# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cardio_train.csv", sep=';')
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# ### 1 . How many rows ans columns are present in datasets?

# %%
df.shape
# Out:
# (70000, 13)

# %% [markdown]
# ### 2. What are the names of all columns?

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# ### 3. See the first 20 Entries

# %%
df.head(20)
# Out:
#     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0    0  18393       2     168    62.0    110     80            1     1      0
# 1    1  20228       1     156    85.0    140     90            3     1      0
# 2    2  18857       1     165    64.0    130     70            3     1      0
# 3    3  17623       2     169    82.0    150    100            1     1      0
# 4    4  17474       1     156    56.0    100     60            1     1      0
# 5    8  21914       1     151    67.0    120     80            2     2      0
# 6    9  22113       1     157    93.0    130     80            3     1      0
# 7   12  22584       2     178    95.0    130     90            3     3      0
# 8   13  17668       1     158    71.0    110     70            1     1      0
# 9   14  19834       1     164    68.0    110     60            1     1      0
# 10  15  22530       1     169    80.0    120     80            1     1      0
# ...

# %% [markdown]
# ### 4. See the last 10 Entries

# %%
df.tail(10)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69990  99986  15094       1     168    72.0    110     70            1     1
# 69991  99988  20609       1     159    72.0    130     90            2     2
# 69992  99990  18792       1     161    56.0    170     90            1     1
# 69993  99991  19699       1     172    70.0    130     90            1     1
# 69994  99992  21074       1     165    80.0    150     80            1     1
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69990      0     0       1       1
# 69991      0     0       1       0
# ...

# %% [markdown]
# ### 5. what is number of observation in datasets ?

# %%
df.shape[0]
# Out:
# 70000

# %% [markdown]
# ### 6. what is the number of columns in datasets ?

# %%
df.shape[1]
# Out:
# 13

# %% [markdown]
# ### 7. What is datatype of each columns ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# ### 8. Summarize the Dataframe

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# ### 9. Are there any missing values?

# %%
df.isnull()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol   gluc  \
# 0      False  False   False   False   False  False  False        False  False
# 1      False  False   False   False   False  False  False        False  False
# 2      False  False   False   False   False  False  False        False  False
# 3      False  False   False   False   False  False  False        False  False
# 4      False  False   False   False   False  False  False        False  False
# ...      ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995  False  False   False   False   False  False  False        False  False
# 69996  False  False   False   False   False  False  False        False  False
# 69997  False  False   False   False   False  False  False        False  False
# 69998  False  False   False   False   False  False  False        False  False
# 69999  False  False   False   False   False  False  False        False  False
#
# ...

# %% [markdown]
# ### 10. How many patients have cardiovascular disease?

# %%
df[df['cardio'] == 1]['cardio'].count()
# Out:
# np.int64(34979)

# %% [markdown]
# ### 11. How many patients do not have cardiovascular disease?

# %%
df[df['cardio']==0]['cardio'].count()
# Out:
# np.int64(35021)

# %% [markdown]
# ### 12. What is the minimum and maximum age?

# %%
df['age_year'] = df['age']/365
df['age_year']
# Out:
# 0        50.391781
# 1        55.419178
# 2        51.663014
# 3        48.282192
# 4        47.873973
#            ...
# 69995    52.712329
# 69996    61.920548
# 69997    52.235616
# 69998    61.454795
# 69999    56.273973
# Name: age_year, Length: 70000, dtype: float64

# %%
df['age_year'].min()
# Out:
# 29.583561643835615

# %%
df['age_year'].max()
# Out:
# 64.96712328767123

# %% [markdown]
# ### 13. What is Avg age

# %%
df['age_year'].mean()
# Out:
# np.float64(53.33935839530333)

# %% [markdown]
# ## 14. Count total Male and Female

# %%
# 1-women and 2-men
male_count = df[df['gender']==2]['gender.count()
male_count
# Out:
# np.int64(24470)

# %%
female_count = df[df['gender']==1]['gender'].count()
female_count
# Out:
# np.int64(45530)

# %% [markdown]
# ### 15. Which gender has more cardiovascular disease?

# %%
if female_count>male_count:
    print("Females has more cardiovascular")
else:
    print("Male has more cardiovascular")
# Out:
# Females has more cardiovascular

# %% [markdown]
# ### 16. What is average height and weight?

# %%
print("Average Height:", df["height"].mean())
print("Average Weight:", df["weight"].mean())
# Out:
# Average Height: 164.35922857142856
# Average Weight: 74.20569

# %% [markdown]
# ### 17. Find tallest and shortest patient

# %%
df["height"].max()
# Out:
# 250

# %%
df["height"].min()
# Out:
# 55

# %% [markdown]
# ### 18. Create BMI and analyze disease.

# %%
df['BMI'] = (df['weight'])/((df['height']/100)**2)
df['BMI']
# Out:
# 0        21.967120
# 1        34.927679
# 2        23.507805
# 3        28.710479
# 4        23.011177
#            ...
# 69995    26.927438
# 69996    50.472681
# 69997    31.353579
# 69998    27.099251
# 69999    24.913495
# Name: BMI, Length: 70000, dtype: float64

# %% [markdown]
# ### 19. Average systolic BP (ap_hi) and diastolic BP (ap_lo).

# %%
df['ap_hi'].mean()
# Out:
# np.float64(128.8172857142857)

# %%
df['ap_lo'].mean()
# Out:
# np.float64(96.63041428571428)

# %% [markdown]
# ### 20. Which gender has more smokers ?

# %%
male_smoker = df[df['gender'] == 2]['gender'].count()
male_smoker
# Out:
# np.int64(24470)

# %%
female_smoker = df[df['gender'] == 1]['gender'].count()
female_smoker
# Out:
# np.int64(45530)

# %%
if male_smoker>female_smoker:
    print("Male")
else:
    print("Female")
# Out:
# Female
